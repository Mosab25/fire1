# %%
MY_SECRET_KEY="tBbpPTxabdvifg1HHGrQ"

# %%
# !pip install roboflow

# from roboflow import Roboflow
# rf = Roboflow(api_key="tBbpPTxabdvifg1HHGrQ")
# project = rf.workspace("-jwzpw").project("continuous_fire")
# version = project.version(6)
# dataset = version.download("yolov8")

# %%
# !pip install ultralytics
# !pip install roboflow

# %%
import ultralytics
from roboflow import Roboflow
from ultralytics import YOLO
from IPython.display import Image

# %%
rf = Roboflow(api_key=MY_SECRET_KEY)
project = rf.workspace("-jwzpw").project("continuous_fire")
dataset = project.version(6).download("yolov8")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...

# %%
# !yolo task=detect mode=train model=yolov8s.pt data=C:/Users/Downloads/machine_learning-master/yolov8-on-fire-colab/continuous_fire-6/data.yaml epochs=10 imgsz=640 plots=True
# Out:
# New https://pypi.org/project/ultralytics/8.3.123 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics 8.3.95 🚀 Python-3.12.9 torch-2.6.0+cpu CPU (12th Gen Intel Core(TM) i7-12700H)
# ...

# %%
# VIEW MODEL TRANING CHARTS
Image(filename=r'C:\Users\runs\detect\train10\results.png', width=600)

# %%
# VALIDATION
# !yolo task=detect mode=val model=C:/Users/runs/detect/train10/weights/best.pt data=C:/Users/Downloads/machine_learning-master/yolov8-on-fire-colab/continuous_fire-6/data.yaml
# Out:
# Ultralytics 8.3.95 🚀 Python-3.12.9 torch-2.6.0+cpu CPU (12th Gen Intel Core(TM) i7-12700H)
# Model summary (fused): 72 layers, 11,125,971 parameters, 0 gradients, 28.4 GFLOPs
#                    all        754        950      0.412      0.395      0.329      0.163
# Speed: 0.5ms preprocess, 118.6ms inference, 0.0ms loss, 1.0ms postprocess per image
# Results saved to C:\Users\Refo\runs\detect\val
# 💡 Learn more at https://docs.ultralytics.com/modes/val
# val: Scanning C:\Users\Refo\Downloads\machine_learning-master\yolov8-on-fire-colab\continuous_fire-6\valid\labels.cache... 754 images, 2 backgrounds, 0 corrupt: 100%|██████████| 754/754 [00:00<?, ?it/s]
# val: Scanning C:\Users\Refo\Downloads\machine_learning-master\yolov8-on-fire-colab\continuous_fire-6\valid\labels.cache... 754 images, 2 backgrounds, 0 corrupt: 100%|██████████| 754/754 [00:00<?, ?it/s]
#
# ...
